# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
def llm(prompt):
    response = openai_client.responses.create(
        model="gpt-5.4-mini",
        input=prompt
    )
    return response.output_text

# %%
llm("Hey, what's up?")
# Out:
# 'Hey! Not much—how can I help?'

# %%
question = "I just discovered the course. Can I join now?"
answer = llm(question)
print(answer)
# Out:
# Yes — if the course is still open, you can usually join now.
#
# A few quick checks:
# - **Enrollment deadline:** some courses accept late sign-ups, others don’t.
# - **Prerequisites:** make sure you meet any required background or placement.
# - **Access to materials:** if the course has already started, you may need to catch up on missed content.
# - **Waitlist or approval:** some courses require instructor approval.
#
# If you want, I can help you draft a short message to the course organizer asking whether late enrollment is possible.
